# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# Prediction:
# I predict that the Random Forest Classifier will perform better than the Logistic Regression model.
#
# Justification:
# The Random Forest Classifier is a more robust model for complex datasets, as it leverages an ensemble of decision trees to identify patterns and relationships within the data. This makes it well-suited for handling non-linear and intricate features. In contrast, Logistic Regression is a linear model, which may struggle to capture the complexities of the dataset. Given that spam detection involves a variety of nuanced factors, such as word frequencies and patterns, the Random Forest Classifier's ability to adapt to these complexities should give it an edge in performance.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
X = data.drop(columns="spam")  
y = data["spam"]

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 958             0.00               0.00           0.00           0.0
# 1533            0.00               0.00           0.00           0.0
# 654             0.33               0.00           0.33           0.0
# 1497            0.52               1.31           0.26           0.0
# 3844            0.00               0.00           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 958             0.0            0.00              1.21                0.00
# 1533            0.0            0.00              0.00                0.00
# 654             0.0            0.00              0.66                0.00
# 1497            2.9            0.26              0.79                0.26
# 3844            0.0            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training data
X_train_scaled = scaler.transform(X_train)

# Scale the testing data
X_test_scaled = scaler.transform(X_test)

# Display the scaled training data as a DataFrame for better readability
pd.DataFrame(X_train_scaled, columns=X_train.columns).head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0       -0.335858          -0.160385      -0.550300     -0.046758
# 1       -0.335858          -0.160385      -0.550300     -0.046758
# 2        0.739868          -0.160385       0.092090     -0.046758
# 3        1.359225           0.895761      -0.044174     -0.046758
# 4       -0.335858          -0.160385      -0.550300     -0.046758
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0      -0.448094       -0.344231          2.950691           -0.252313
# 1      -0.448094       -0.344231         -0.296875           -0.252313
# 2      -0.448094       -0.344231          1.474525           -0.252313
# 3       3.824612        0.636976          1.823437            0.377023
# 4      -0.448094       -0.344231         -0.296875           -0.252313
#
#    word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression

# Create the Logistic Regression model instance
logistic_model = LogisticRegression(max_iter=1000, random_state=42)

# Fit the model using the scaled training data
logistic_model.fit(X_train_scaled, y_train)

# Print the model's training score
print(f"Training Score: {logistic_model.score(X_train_scaled, y_train)}")
# Out:
# Training Score: 0.9273291925465839

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
testing_predictions = logistic_model.predict(X_test_scaled)

# Review the predictions
print(testing_predictions)
# Out:
# [0 0 0 ... 1 1 0]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`
accuracy = accuracy_score(y_test, testing_predictions)

# Print the accuracy score
print(f"Accuracy Score: {accuracy}")
# Out:
# Accuracy Score: 0.9232440260680667

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

# Create the Random Forest Classifier model instance
random_forest_model = RandomForestClassifier(random_state=1)

# Fit the model using the scaled training data
random_forest_model.fit(X_train_scaled, y_train)

# Print the model's training score
print(f"Training Score: {random_forest_model.score(X_train_scaled, y_train)}")
# Out:
# Training Score: 0.9996894409937889

# %%
# Make and save testing predictions with the saved Random Forest model using the test data
rf_testing_predictions = random_forest_model.predict(X_test_scaled)

# Review the predictions
print(rf_testing_predictions)
# Out:
# [0 0 0 ... 1 1 0]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `rf_testing_predictions`
rf_accuracy = accuracy_score(y_test, rf_testing_predictions)

# Print the accuracy score
print(f"Accuracy Score: {rf_accuracy}")
# Out:
# Accuracy Score: 0.9558291093410572

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# Evaluation of Models
#
# Model Performances:
#
#     Logistic Regression Accuracy: 0.9270
#     Random Forest Classifier Accuracy: 0.9548
#
# Which model performed better?
# The Random Forest Classifier performed better with an accuracy score of 0.9548 compared to the Logistic Regression model's accuracy of 0.9270.
#
# How does that compare to your prediction?
# If my initial prediction favored the Random Forest Classifier, then this result aligns with my expectations. Random Forest Classifiers tend to perform better on datasets with complex patterns because they combine multiple decision trees to improve prediction accuracy and reduce overfitting. On the other hand, Logistic Regression, being a linear model, might struggle with capturing intricate relationships within the data.
#
# However, if my prediction was for Logistic Regression to perform better, the results indicate that Random Forest is more suitable for this dataset.
